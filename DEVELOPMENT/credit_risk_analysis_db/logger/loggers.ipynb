# %%
import logging
import sys
from datetime import datetime

# %%
def get_logger(logger_name):

    logger = logging.getLogger(logger_name)

    logger.setLevel(logging.INFO)

    if logger.hasHandlers():
        logger.handlers.clear()

    formatter = logging.Formatter(

        "%(asctime)s | %(levelname)s | %(name)s | %(message)s",

        datefmt="%Y-%m-%d %H:%M:%S"

    )

    console = logging.StreamHandler(sys.stdout)

    console.setFormatter(formatter)

    logger.addHandler(console)

    return logger

# %%
def log_info(logger, message):

    logger.info(message)

# %%
def log_warning(logger, message):

    logger.warning(message)

# %%
def log_error(logger, message):

    logger.error(message)

# %%
def log_exception(logger, exception):

    logger.exception(exception)

# %%
logger = get_logger("CREDIT_RISK_PIPELINE")

log_info(logger, "Logger Initialized Successfully")

log_warning(logger, "Sample Warning")

log_error(logger, "Sample Error")
# Out:
# 2026-07-12 03:20:14 | INFO | CREDIT_RISK_PIPELINE | Logger Initialized Successfully
# 2026-07-12 03:20:14 | WARNING | CREDIT_RISK_PIPELINE | Sample Warning
# 2026-07-12 03:20:14 | ERROR | CREDIT_RISK_PIPELINE | Sample Error
